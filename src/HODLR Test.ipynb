# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Plot O(n2) and O(nlog2n)
x = np.arange(0.01, 10000., 0.01)
plt.plot(x, x**2, '-',
         x, x * np.log2(x), '-',
         linewidth=1)
plt.show()
